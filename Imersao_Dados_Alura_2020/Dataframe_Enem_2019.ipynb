# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoCioffi/Imersao_Dados/blob/main/Dataframe_Enem_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 01: Dados de Educação**

# %% [markdown]
# ###**IMPORTAÇÃO BIBLIOTECAS**

# %%
import pandas               as pd
import numpy                as np

# %% [markdown]
# ###**IMPORTAÇÃO DO DATASET**

# %%
fonte = "https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv"

df = pd.read_csv(fonte)

# %% [markdown]
# ###**EXPLORAÇÃO DO DATASET**

# %%
# 3 primeirosdados do dataframe
df.head(3)
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
#
# [3 rows x 136 columns]

# %%
# Tamanho do dataframe
print(f'Total de linhas: {df.shape[0]} ; Total de colunas : {df.shape[1]}')
# Out:
# Total de linhas: 127380 ; Total de colunas : 136

# %%
# Visualizando as colunas
df.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
# Visualizando a quantidade de dados por estado
df['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
# Visualizando e contando os alunos por idade - Ordenação por quantidade de alunos
df['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
# Visualizando o menor e a maior idade
print('O aluno mais novo deste dataset tem {} anos e o mais velho {} anos'.format(df['NU_IDADE'].min(), 
                                                                                  df['NU_IDADE'].max()))
# Out:
# O aluno mais novo deste dataset tem 13 anos e o mais velho 82 anos

# %%
# Separarando os dados somente dos alunos que são treineiros e contar pela idade
df.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %% [markdown]
# ###**HISTOGRAMA**

# %%
df['NU_IDADE'].hist()

# %%
# Alterando a quantidade de bins
df['NU_IDADE'].hist(bins = 20)

# %%
# Histograma das notas de redação
df['NU_NOTA_REDACAO'].hist(bins=20)

# %% [markdown]
# ###**ANALISES ESTATÍSTICAS DESCRITIVAS**

# %%
# Media
df['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
# Desvio padrao
df['NU_NOTA_REDACAO'].std()
# Out:
# 188.07645455749753

# %%
# Selecionando somente as colunas de notas
provas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_MT', 'NU_NOTA_LC', 'NU_NOTA_REDACAO']

# Visualizando as estatisticas descritivas basicas
df[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
# Visualizando os 10% mais baixo
df['NU_NOTA_LC'].quantile(0.9)
# Out:
# 596.3

# %% [markdown]
# ###**BOXPLOT**

# %%
df['NU_NOTA_LC'].plot.box(grid = True, figsize =(10, 6))

# %%
df[provas].boxplot(figsize=(14,8))

# %% [markdown]
# ###Desafio01: Proporção dos inscritos por idade.
#
# ###Desafio02: Descobrir de quais estados são os inscritos com 13 anos.
#
# ###Desafio03: Adicionar título no gráfico
#
# ###Desafio04: Plotar os Histogramas das idades dos do treineiro e não treineiros.
#
# ###Desafio05: Comparar as distribuições das provas em inglês espanhol
#
# ###Desafio06: Explorar a documentações e visualizações com matplotlib ou pandas e gerar novas visualizações.

# %% [markdown]
# ###**Resolução:**

# %%
#DESAFIO 01:

pd.options.display.float_format = '{:,.2f}'.format ##display da casa decimal

# Contagem dos alunos por idade
alunos_por_idade_qt = df['NU_IDADE'].value_counts().sort_index()

# % dos alunos por idade
alunos_por_idade_per = (df['NU_IDADE'].value_counts(normalize=True).sort_index()) *100

# Inserindo as duas variáveis em um DataFrame
alunos_por_idade = pd.DataFrame({'NU_IDADE' : alunos_por_idade_qt,
                                 'PERC_IDADE': alunos_por_idade_per})

alunos_por_idade
# Out:
#     NU_IDADE  PERC_IDADE
# 13         4        0.00
# 14       141        0.11
# 15      2009        1.58
# 16      7830        6.15
# 17     21256       16.69
# ..       ...         ...
# 73         2        0.00
# 75         2        0.00
# 76         1        0.00
# 77         1        0.00
# 82         1        0.00
#
# [65 rows x 2 columns]

# %%
#DESAFIO 02:

# Query para buscar alunos com idade igual a 13 anos
df.query('NU_IDADE == 13')['SG_UF_RESIDENCIA']
# Out:
# 57359     SP
# 95630     MT
# 98197     AP
# 116501    BA
# Name: SG_UF_RESIDENCIA, dtype: object

# %% [markdown]
# #**AULA 02: Análise Exploratória**

# %%
df.query("NU_IDADE == 13")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %%
df.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# SP    11
# MG    11
# MA     9
# PB     7
# GO     7
# PI     7
# AM     4
# MT     4
# DF     4
# SE     3
# TO     3
# PR     3
# SC     2
# RO     2
# AL     2
# RJ     1
# AC     1
# ES     1
# RN     1
# RS     1
# AP     1
# MS     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
df.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# PE   0.12
# CE   0.10
# BA   0.10
# PA   0.08
# SP   0.08
# MG   0.08
# MA   0.06
# PB   0.05
# GO   0.05
# PI   0.05
# AM   0.03
# MT   0.03
# DF   0.03
# SE   0.02
# TO   0.02
# PR   0.02
# SC   0.01
# RO   0.01
# AL   0.01
# RJ   0.01
# AC   0.01
# ES   0.01
# RN   0.01
# RS   0.01
# AP   0.01
# MS   0.01
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
alunos_menor_quartoze = df.query("NU_IDADE <= 14")
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts().plot.pie(figsize=(10,8))

# %%
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts(normalize = True).plot.bar(figsize=(10,8))

# %%
len(alunos_menor_quartoze)
# Out:
# 145

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.boxplot(x="Q006", y = "NU_NOTA_MT", data = df)
plt.title("Boxplot das notas de matemática pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda')

# %%
renda_ordenada = df['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10, 8))
sns.boxplot(x='Q006', y = 'NU_NOTA_MT', data = df, order = renda_ordenada)
plt.title('Boxplot das notas de matematica pela renda')
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matematica pela renda')

# %%
# Somando as colunas
df[provas].sum()
# Out:
# NU_NOTA_CN        44,334,986.10
# NU_NOTA_CH        49,743,676.10
# NU_NOTA_MT        48,563,933.80
# NU_NOTA_LC        51,027,844.90
# NU_NOTA_REDACAO   56,038,440.00
# dtype: float64

# %%
# Somando as linhas
df['NU_NOTA_TOTAL'] = df[provas].sum(axis=1)
df.head(3)
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B      2,288.90
# 1  190001004674    2019                  1504208  ...    A     B      1,184.60
# 2  190001004722    2019                  1501402  ...    A     B      2,350.50
#
# [3 rows x 137 columns]

# %%
# Boxplot das notas por renda
plt.figure(figsize=(10, 8))
sns.boxplot(x='Q006', y = 'NU_NOTA_TOTAL', data = df, order = renda_ordenada)
plt.title('boxplot das notas de total pela renda')
# Out:
# Text(0.5, 1.0, 'boxplot das notas de total pela renda')

# %%
# Analisando a distribuicao de notas totais
sns.displot(df, x='NU_NOTA_TOTAL')

# %%
provas.append('NU_NOTA_TOTAL')
df[provas].query('NU_NOTA_TOTAL == 0')
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# 10             nan         nan  ...              nan           0.00
# 11             nan         nan  ...              nan           0.00
# 26             nan         nan  ...              nan           0.00
# 38             nan         nan  ...              nan           0.00
# 40             nan         nan  ...              nan           0.00
# ...            ...         ...  ...              ...            ...
# 127351         nan         nan  ...              nan           0.00
# 127365         nan         nan  ...              nan           0.00
# 127366         nan         nan  ...              nan           0.00
# 127368         nan         nan  ...              nan           0.00
# 127374         nan         nan  ...              nan           0.00
#
# [29162 rows x 6 columns]

# %%
# Criando variavel para excluir os alunos com nota != de 0
dados_sem_nota_zero = df.query('NU_NOTA_TOTAL != 0')
dados_sem_nota_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B      2,288.90
# 1  190001004674    2019                  1504208  ...    A     B      1,184.60
# 2  190001004722    2019                  1501402  ...    A     B      2,350.50
# 3  190001004735    2019                  1507300  ...    A     B      2,555.70
# 4  190001004776    2019                  1500800  ...    A     B      2,803.50
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Q006', y='NU_NOTA_TOTAL', data = dados_sem_nota_zero, order = renda_ordenada)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='Q006', y='NU_NOTA_TOTAL', data = dados_sem_nota_zero, hue = 'IN_TREINEIRO',order = renda_ordenada)

# %% [markdown]
# ###MEGA DESAFIO DA THAINÁ: Pegar a amostra completa dos alunos de 13 e 14 anos
#
# ###Desafio do Gui bonzinho: aumentar a amostra para alunos menor de idade e compara a proporção por estado.
#
# ###Desafio 3: Criar uma função para plotar o boxplot do seaborn
#
# ###Desafio 4: Verificar se quem zerou a prova foi eliminado ou não estava presente
#
# ###Desafio 5: Quem é eliminado tira zero ou será NaN (não teve registro de notas)
#
# ###Desafio 6: Verificar a proporção dos participantes de rendas mais altas e mais baixas como treineiro e não treineiro.
#
# ###Desafio 7: Fazer o mesmo boxplot olhando para a questão 25 (tem internet ou não) e fazer uma reflexão sobre o assunto e o contexto de pandemia.

# %% [markdown]
# #**AULA 03: Distribuições e Correlações**

# %%
plt.figure(figsize=(12, 8))
sns.histplot(dados_sem_nota_zero, x="NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(12, 8))
sns.histplot(dados_sem_nota_zero, x="NU_NOTA_MT")

# %%
plt.figure(figsize=(12, 8))
sns.histplot(dados_sem_nota_zero, x="NU_NOTA_LC")

# %%
plt.figure(figsize=(12, 8))
sns.histplot(dados_sem_nota_zero, x="NU_NOTA_TOTAL", hue = "Q025", kde = True)

# %%
plt.figure(figsize=(12, 8))
sns.histplot(dados_sem_nota_zero, x="NU_NOTA_TOTAL", hue = "Q025", kde = True, stat = "density", cumulative = True)

# %%
plt.figure(figsize = (10, 10))
sns.scatterplot(data = dados_sem_nota_zero, x = "NU_NOTA_MT", y = "NU_NOTA_LC", hue = "Q025")
plt.xlim((0, 1000))
plt.ylim((0, 1000))
# Out:
# (0.0, 1000.0)

# %%
sns.pairplot(dados_sem_nota_zero[provas])

# %%
correlacao = dados_sem_nota_zero[provas].corr()
"""
OBS:  correlação entre variáveis (Pearson Correlation) no gráfico de dispersão 
                          -1 <= corr <= 1 
         -1: variáveis inversamente proporcionais
          0: variáveis sem correlação
           1: variáveis diretamente proporcionais 
"""
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN             1.00        0.67  ...             0.50           0.79
# NU_NOTA_CH             0.67        1.00  ...             0.53           0.74
# NU_NOTA_MT             0.65        0.61  ...             0.49           0.79
# NU_NOTA_LC             0.64        0.74  ...             0.54           0.71
# NU_NOTA_REDACAO        0.50        0.53  ...             1.00           0.78
# NU_NOTA_TOTAL          0.79        0.74  ...             0.78           1.00
#
# [6 rows x 6 columns]

# %%
sns.heatmap(correlacao, cmap = "Oranges", center = 0, annot = True)

# %% [markdown]
# ###Desafio1: Plotar as médias, medianas e moda nas notas de LC e MT (matiplotlib linha vt)
#
# ###Desafio2: Plotar a matriz de correlação considerando apenas uma triangulação (superior ou inferior)
#
# ###Desafio3: Filtrar as notas por seu estado ou cidade e refazer as análises verificando se possuem comportamento similar ao global
#
# ###Desafio4: Pensar sobre a correlação entre matemática e linguagens

# %% [markdown]
# #**AULA 04: Machine Learning**

# %%
provas_entrada = ["NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
prova_saida = "NU_NOTA_MT"

dados_sem_nota_zero = dados_sem_nota_zero[provas].dropna()

notas_entrada = dados_sem_nota_zero[provas_entrada]
notas_saida = dados_sem_nota_zero[prova_saida]

# %%
notas_entrada
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_REDACAO
# 0           512.30      488.60           420.00
# 2           499.10      441.00           560.00
# 3           578.10      551.50           500.00
# 4           571.30      511.20           780.00
# 5           618.70      607.50           900.00
# ...            ...         ...              ...
# 127373      501.50      485.30           520.00
# 127375      559.60      525.70           740.00
# 127376      380.90      450.30           520.00
# 127378      416.20      517.30           620.00
# 127379      425.50      477.10           480.00
#
# [92537 rows x 3 columns]

# %%
x = notas_entrada
y = notas_saida

# %%
from sklearn.model_selection import train_test_split

SEED = 111    #-> número arbitrário (evita a influência do random_state nos resultados)

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state = SEED)

# %%
x_treino.head()
# Out:
#         NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_REDACAO
# 37988       616.50      640.60           620.00
# 28820       555.60      538.40           580.00
# 49410       601.20      613.60           940.00
# 109270      327.30      446.80           240.00
# 83073       542.40      476.80           480.00

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=111, tol=0.0001, verbose=0)

# %%
predicoes_matematica = modelo.predict(x_teste)

# %%
y_teste[:5]
# Out:
# 89978    492.90
# 42063    465.40
# 117390   452.60
# 57654    449.70
# 43894    419.40
# Name: NU_NOTA_MT, dtype: float64

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = predicoes_matematica, y = y_teste)
plt.xlim((0, 1000))
plt.ylim((0, 1000))
# Out:
# (0.0, 1000.0)

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = y_teste, y = y_teste - predicoes_matematica)
plt.xlim((0, 1000))
plt.ylim((0, 1000))
# Out:
# (0.0, 1000.0)

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x = y_teste, y = x_teste.mean(axis = 1))
plt.xlim((0, 1000))
plt.ylim((0, 1000))
# Out:
# (0.0, 1000.0)

# %%
resultados = pd.DataFrame()

resultados["Real"] = y_teste
resultados["Previsão"] = predicoes_matematica
resultados["Diferença"] =(resultados["Real"] - resultados["Previsão"])
resultados["Quadrado_Diferença"] =(resultados["Real"] - resultados["Previsão"])**2

resultados
# Out:
#          Real  Previsão  Diferença  Quadrado_Diferença
# 89978  492.90    416.65      76.25            5,814.79
# 42063  465.40    437.57      27.83              774.32
# 117390 452.60    445.27       7.33               53.72
# 57654  449.70    310.41     139.29           19,403.06
# 43894  419.40    346.60      72.80            5,300.31
# ...       ...       ...        ...                 ...
# 116768 637.40    509.00     128.40           16,487.09
# 53904  680.50    520.26     160.24           25,677.11
# 59784  620.40    460.05     160.35           25,713.50
# 37365  797.10    549.48     247.62           61,317.91
# 59749  564.90    433.24     131.66           17,333.41
#
# [23135 rows x 4 columns]

# %%
resultados["Quadrado_Diferença"].mean()
# Out:
# 15010.498596063053

# %%
resultados["Quadrado_Diferença"].mean()**(1/2)
# Out:
# 122.51733998117594

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12163.511726221017

# %%
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 15010.498596063026

# %% [markdown]
# ###Desafio1: Procurar outro modelo de ML para treinar e comparar com os modelos criados em aula
#
# ###Desafio2: Ler a documentação do Dummy e alterar o método de regressão
#
# ###Desafio3: Buscar outra métrica para avaliar modelos de regressão

# %% [markdown]
# #**AULA 05: Validação de Modelo e Overfit**

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
predicoes_matematica = modelo.predict(x_teste)
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 15010.498596063026

# %%
from sklearn.tree import DecisionTreeRegressor

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25)

modelo_arvore = DecisionTreeRegressor(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_matematica_arvore = modelo_arvore.predict(x_teste)

mean_squared_error(y_teste, predicoes_matematica_arvore)
# Out:
# 6435.001314544234

# %%
def calcula_mse(resultados):
        media = (resultados["test_score"] * -1).mean()
        desvio_padrao = (resultados["test_score"] * -1).std()
        lim_inferior = media - (2 * desvio_padrao)
        lim_superior = media + (2 * desvio_padrao)
        print(f'Intervalo de confiança: [{lim_inferior} ; {lim_superior}]')

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
import numpy as np

SEED = 111
np.random.seed(SEED)

partes = KFold(n_splits = 10, shuffle = True)
modelo_arvore = DecisionTreeRegressor(max_depth = 3)
resultados = cross_validate(modelo_arvore, x, y, cv = partes, scoring = "neg_mean_squared_error")

calcula_mse(resultados)
# Out:
# Intervalo de confiança: [6295.418743566298 ; 6560.904366929305]

# %%
def regressor_arvore(nivel):
        SEED = 111
        np.random.seed(SEED)
        partes = KFold(n_splits = 10, shuffle = True)
        modelo_arvore = DecisionTreeRegressor(max_depth = nivel)
        resultados = cross_validate(modelo_arvore, x, y, cv = partes, scoring = "neg_mean_squared_error", return_train_score = True)
        print(f"Treino = {(resultados['train_score']*-1).mean()} | Teste = {(resultados['test_score']*-1).mean()}")

# %%
for i in range(1, 21):
          regressor_arvore(i)
# Out:
# Treino = 8040.881709963939 | Teste = 8053.163546268146
# Treino = 6795.662773934149 | Teste = 6831.020052442278
# Treino = 6387.66231455613 | Teste = 6428.1615552478015
# Treino = 6131.520261677613 | Teste = 6181.446323365943
# Treino = 5975.740783817464 | Teste = 6041.972997720604
# Treino = 5875.459523933294 | Teste = 5960.697520422288
# Treino = 5802.019359638579 | Teste = 5935.122655665495
# Treino = 5728.837596113421 | Teste = 5961.6096329226275
# Treino = 5630.71353541369 | Teste = 6064.193627637147
# Treino = 5490.793765317124 | Teste = 6199.928591357397
# Treino = 5301.121167625554 | Teste = 6383.508809707955
# Treino = 5060.5414176635895 | Teste = 6654.081756732317
# Treino = 4774.223781535211 | Teste = 6946.897202231927
# Treino = 4444.270355630124 | Teste = 7298.730629791942
# Treino = 4084.067637810801 | Teste = 7690.4246811217035
# Treino = 3699.9234321627446 | Teste = 8105.1543322189045
# Treino = 3305.4176117379056 | Teste = 8525.947392087144
# ...

# %% [markdown]
# ###Desafio1: Pesquisar sobre intervalo de confiança
#
# ###Desafio2: Testar com outros parâmetros da árvore de decisão
#
# ###Desafio3: Procurar outras formas de realizar os ajustes de parâmetros com Sklearn
#
# ###Desafio4: Pesquisar o que é problema de 'underfit'
#
# ###Desafio5: Plotar um gráfico com test_score e train_test
